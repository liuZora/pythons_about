# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 读取数据
# - AAPL.CSV文件

# %%
apple = pd.read_csv('data/11_苹果股票分析项目/AAPL.csv')
apple
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.513393    0.515625    0.513393    0.513393    0.421597
# 1     1980-12-15    0.488839    0.488839    0.486607    0.486607    0.399601
# 2     1980-12-16    0.453125    0.453125    0.450893    0.450893    0.370272
# 3     1980-12-17    0.462054    0.464286    0.462054    0.462054    0.379437
# 4     1980-12-18    0.475446    0.477679    0.475446    0.475446    0.390436
# ...          ...         ...         ...         ...         ...         ...
# 9291  2017-10-17  159.779999  160.869995  159.229996  160.470001  160.470001
# 9292  2017-10-18  160.419998  160.710007  159.600006  159.759995  159.759995
# 9293  2017-10-19  156.750000  157.080002  155.020004  155.979996  155.979996
# 9294  2017-10-20  156.610001  157.750000  155.960007  156.250000  156.250000
# 9295  2017-10-23  156.889999  157.690002  155.500000  156.169998  156.169998
#
#          Volume
# 0     117258400
# ...

# %%
apple.shape
# Out:
# (9296, 7)

# %%
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.421597  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.399601   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.370272   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.379437   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.390436   18362400

# %%
apple.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9291  2017-10-17  159.779999  160.869995  159.229996  160.470001  160.470001
# 9292  2017-10-18  160.419998  160.710007  159.600006  159.759995  159.759995
# 9293  2017-10-19  156.750000  157.080002  155.020004  155.979996  155.979996
# 9294  2017-10-20  156.610001  157.750000  155.960007  156.250000  156.250000
# 9295  2017-10-23  156.889999  157.690002  155.500000  156.169998  156.169998
#
#         Volume
# 9291  18997300
# 9292  16374200
# 9293  42584200
# 9294  23974100
# 9295  21867200

# %%
apple.sample(10)
apple.sample(frac=0.001)
# Out:
#             Date        Open        High         Low       Close  Adj Close  \
# 6652  2007-04-26   14.511429   14.642858   14.042857   14.120000  12.703144
# 3111  1993-04-05    1.785714    1.803571    1.767857    1.785714   1.550564
# 5410  2002-05-20    1.755000    1.780714    1.752143    1.767143   1.589821
# 7245  2009-09-01   23.998571   24.285715   23.562857   23.614286  21.244738
# 7223  2009-07-31   23.284286   23.571428   23.272858   23.341429  20.999258
# 510   1982-12-21    0.535714    0.540179    0.526786    0.540179   0.443594
# 2030  1988-12-23    1.464286    1.477679    1.464286    1.468750   1.222480
# 8541  2014-10-24  105.180000  105.489998  104.529999  105.220001  99.530258
# 6367  2006-03-08    9.470000    9.600000    9.335714    9.380000   8.438775
#
#          Volume
# 6652  434444500
# 3111   37293200
# 5410   67478600
# 7245  117257000
# 7223  105634200
# 510    19986400
# 2030   10239600
# 8541   47053900
# 6367  163312800

# %% [markdown]
# #### 检查数据类型

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9296 entries, 0 to 9295
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9296 non-null   object
#  1   Open       9296 non-null   float64
#  2   High       9296 non-null   float64
#  3   Low        9296 non-null   float64
#  4   Close      9296 non-null   float64
#  5   Adj Close  9296 non-null   float64
#  6   Volume     9296 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 508.5+ KB

# %%
apple.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9296.000000  9296.000000  9296.000000  9296.000000  9296.000000
# mean     21.171909    21.374401    20.949917    21.167384    19.888297
# std      37.544405    37.839621    37.222077    37.540368    36.112221
# min       0.198661     0.198661     0.196429     0.196429     0.161307
# 25%       1.031250     1.053571     1.011161     1.031250     0.916267
# 50%       1.625000     1.651786     1.598214     1.624643     1.424670
# 75%      19.855715    20.088214    19.473214    19.833571    17.843392
# max     164.800003   164.940002   163.630005   164.050003   164.050003
#
#              Volume
# count  9.296000e+03
# mean   8.923616e+07
# std    8.731405e+07
# min    3.472000e+05
# 25%    3.507770e+07
# 50%    6.131125e+07
# 75%    1.115664e+08
# max    1.855410e+09

# %% [markdown]
# 将'Date'这列数据转换为时间数据类型
# - pd.to_datetime: 转为时间数据类型

# %%
apple.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.421597  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.399601   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.370272   26432000

# %%
apple['Date'] = pd.to_datetime(apple['Date'])

# %%
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# 将'Date'设置为行索引
# - set_index():设置行索引

# %%
apple2 = apple.set_index('Date')
apple2.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.421597  117258400
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.399601   43971200
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.370272   26432000
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   0.379437   21610400
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   0.390436   18362400

# %% [markdown]
# 绘制图形:收盘价格
# - 字段Adj Close:已调整收盘价格

# %%
apple2['Adj Close'].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>
